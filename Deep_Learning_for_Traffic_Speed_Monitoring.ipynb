# %%
from sort import *

# %%
import ultralytics
from ultralytics import YOLO
import math

# %%
import cv2
import cvzone
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import time
path_of_folder = 'C:/Users/HP/Desktop/jupyterNotebook/projects/photos_of_overspeedCars'
os.makedirs(path_of_folder, exist_ok=True)

# %%
import numpy as np
from tensorflow import keras
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,BatchNormalization,Dropout
from keras import Sequential
from twilio.rest import Client
import tensorflow_datasets as tfds

# %%
speed_limit=2
speeds=0
start_time=0
end_time=0
scale_factor = 0.3
cap = cv2.VideoCapture('C:/Users/HP/Downloads/2103099-uhd_3840_2160_30fps.mp4')
model=YOLO('../YOLO-Weight/yolov8n.pt')
#numbers_of_vehicals=0

classNames = [
    "person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
    "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat", 
    "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella", 
    "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", 
    "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", 
    "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", 
    "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "potted plant", 
    "bed", "dining table", "toilet", "tv monitor", "laptop", "mouse", "remote", "keyboard", "cell phone", 
    "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", 
    "teddy bear", "hair dryer", "toothbrush"
]

# %%
mask=cv2.imread('C:/Users/HP/Downloads/r.png')

tracker=Sort(max_age=20,min_hits=3,iou_threshold=0.3)



totalCount=[]



frame_width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print("frame_width",frame_width)
print("frame_height",frame_height)

mask=cv2.resize(mask,(frame_width,frame_height))
# Out:
# frame_width 3840
# frame_height 2160

# %%
# Initialize time tracking dictionary
vehicle_times = {}

while True:
    success, img = cap.read()
    if not success:
        print("End of video or failed to read frame.")
        break

    # Resize image
    new_width = int(frame_width * scale_factor)
    new_height = int(frame_height * scale_factor)
    img_resized = cv2.resize(img, (new_width, new_height))
    mask = cv2.resize(mask, (new_width, new_height))

    # Apply mask
    imgRegion = cv2.bitwise_and(img_resized, mask)

    # YOLO detection
    results = model(imgRegion, stream=True)
    detections = np.empty((0, 5))

    # Draw lines for vehicle tracking
    line_y1 = int(new_height / 2 - 40)
    line_y2 = int(new_height / 2 + 35)
    cv2.line(img_resized, (0, line_y1), (new_width, line_y1), (200, 100, 255), 5)
    cv2.line(img_resized, (0, line_y2), (new_width, line_y2), (0, 0, 255), 5)

    # Process YOLO results
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            conf = math.ceil((box.conf[0] * 100)) / 100
            cls = int(box.cls[0])

            # Filter relevant classes and confidence
            if conf > 0.3 and cls in [2, 3, 5, 7]:  # Cars, trucks, buses, etc.
                currentArray = np.array([x1, y1, x2, y2, conf])
                detections = np.vstack((detections, currentArray))

                # Draw bounding box and label
                cvzone.cornerRect(img_resized, (x1, y1, x2 - x1, y2 - y1), l=9, rt=4, colorR=(255, 0, 255))
                cvzone.putTextRect(img_resized, f'{conf} {cls}', (max(0, x1), max(35, y1)), scale=0.7, thickness=1)

    # Update tracker
    resultsTracker = tracker.update(detections)
    for result in resultsTracker:
        x1, y1, x2, y2, id = result
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        cx, cy = x1 + (x2 - x1) // 2, y1 + (y2 - y1) // 2

        # Draw tracker info
        cvzone.cornerRect(img_resized, (x1, y1, x2 - x1, y2 - y1), l=9, rt=4, colorR=(0, 255, 0))
        cvzone.putTextRect(img_resized, f'ID: {int(id)}', (max(0, x1), max(35, y1)), scale=0.7, thickness=1)
        cv2.circle(img_resized, (cx, cy), 5, (255, 0, 255), cv2.FILLED)

        # Track vehicle crossing the first line
        if line_y1 - 20 < cy < line_y1 + 20:
            if id not in vehicle_times:
                vehicle_times[id] = {'start_time': time.time(), 'end_time': None}
            cv2.line(img_resized, (0, line_y1), (new_width, line_y1), (0, 255, 0), 5)

        # Track vehicle crossing the second line
        if line_y2 - 20 < cy < line_y2 + 20 and vehicle_times.get(id, {}).get('start_time') is not None:
            vehicle_times[id]['end_time'] = time.time()

            # Calculate speed if not already calculated
            start_time = vehicle_times[id]['start_time']
            end_time = vehicle_times[id]['end_time']
            if start_time and end_time:
                elapsed_time = end_time - start_time
                distance = 10  # Example: 10 meters between the lines
                speed = distance / elapsed_time * 3.6  # Speed in km/h (convert m/s to km/h)

                print(f"Vehicle ID {id} Speed: {speed:.2f} km/h")
                if speed > speed_limit:
                    photo_name = f"overspeed_{id}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.jpg"
                    cv2.imwrite(os.path.join(path_of_folder, photo_name), img_resized)
                    
                    print(f"Vehicle ID {id} exceeded speed limit! Speed: {speed:.2f} km/h")
                else:
                    print(f"Vehicle ID {id} is within speed limit.")

    # Display count
    cvzone.putTextRect(img_resized, f'Count: {len(vehicle_times)}', (50, 50), scale=1, thickness=2)

    # Show the output
    cv2.imshow("Video", img_resized)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 12 cars, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 57.2ms
# Speed: 8.1ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 53.3ms
# Speed: 15.8ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 62.3ms
# Speed: 1.5ms preprocess, 62.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 70.6ms
# Speed: 14.8ms preprocess, 70.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 67.4ms
# Speed: 0.0ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 52.7ms
# Speed: 3.2ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 51.8ms
# Speed: 3.3ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 51.9ms
# Speed: 4.8ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 75.4ms
# Speed: 0.0ms preprocess, 75.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 58.9ms
# Speed: 3.2ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 60.2ms
# Speed: 3.2ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 59.1ms
# Speed: 9.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 54.2ms
# Speed: 3.0ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 56.1ms
# Speed: 1.8ms preprocess, 56.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 52.4ms
# Speed: 2.7ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 67.5ms
# Speed: 0.0ms preprocess, 67.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 69.7ms
# Speed: 2.0ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 83.9ms
# Speed: 15.8ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 95.0ms
# Speed: 3.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 102.2ms
# Speed: 3.2ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 99.8ms
# Speed: 2.9ms preprocess, 99.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 100.6ms
# Speed: 6.8ms preprocess, 100.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 89.0ms
# Speed: 4.4ms preprocess, 89.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 101.6ms
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 82.0ms
# Speed: 2.5ms preprocess, 82.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 113.5ms
# Speed: 9.2ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 79.1ms
# Speed: 3.4ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 80.4ms
# Speed: 14.4ms preprocess, 80.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 90.1ms
# Speed: 13.1ms preprocess, 90.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 86.1ms
# Speed: 3.1ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 103.1ms
# Speed: 15.6ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 76.5ms
# Speed: 3.7ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 85.4ms
# Speed: 3.0ms preprocess, 85.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 77.8ms
# Speed: 10.6ms preprocess, 77.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 105.9ms
# Speed: 0.0ms preprocess, 105.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 98.2ms
# Speed: 3.5ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 82.5ms
# Speed: 0.0ms preprocess, 82.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 71.2ms
# Speed: 12.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 83.4ms
# Speed: 0.0ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 101.1ms
# Speed: 0.0ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 68.9ms
# Speed: 13.2ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 113.2ms
# Speed: 0.0ms preprocess, 113.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 87.7ms
# Speed: 1.8ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 78.8ms
# Speed: 2.7ms preprocess, 78.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 80.5ms
# Speed: 3.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 84.0ms
# Speed: 3.2ms preprocess, 84.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 78.8ms
# Speed: 11.1ms preprocess, 78.8ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 103.1ms
# Speed: 3.3ms preprocess, 103.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 117.0ms
# Speed: 0.0ms preprocess, 117.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 81.4ms
# Speed: 3.0ms preprocess, 81.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 77.9ms
# Speed: 3.3ms preprocess, 77.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 75.6ms
# Speed: 3.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 68.7ms
# Speed: 4.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 89.2ms
# Speed: 10.8ms preprocess, 89.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 81.5ms
# Speed: 4.0ms preprocess, 81.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 85.6ms
# Speed: 4.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 80.8ms
# Speed: 3.7ms preprocess, 80.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 91.9ms
# Speed: 5.9ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 67.8ms
# Speed: 3.6ms preprocess, 67.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 73.6ms
# Speed: 5.2ms preprocess, 73.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 86.4ms
# Speed: 5.2ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.26 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.26 km/h
#
# 0: 384x640 12 cars, 81.7ms
# Speed: 3.0ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.21 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.21 km/h
#
# 0: 384x640 12 cars, 65.9ms
# Speed: 5.0ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.18 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.18 km/h
#
# 0: 384x640 13 cars, 75.2ms
# Speed: 3.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.14 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.14 km/h
#
# 0: 384x640 12 cars, 119.0ms
# Speed: 3.4ms preprocess, 119.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.10 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.10 km/h
#
# 0: 384x640 13 cars, 97.4ms
# Speed: 0.0ms preprocess, 97.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.07 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.07 km/h
#
# 0: 384x640 12 cars, 70.8ms
# Speed: 9.7ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.04 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.04 km/h
#
# 0: 384x640 12 cars, 79.8ms
# Speed: 6.2ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 2.00 km/h
# Vehicle ID 479.0 exceeded speed limit! Speed: 2.00 km/h
#
# 0: 384x640 12 cars, 76.1ms
# Speed: 3.0ms preprocess, 76.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.97 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 14 cars, 63.1ms
# Speed: 4.7ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.94 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 14 cars, 70.8ms
# Speed: 3.2ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.91 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 10 cars, 74.7ms
# Speed: 8.1ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.89 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 11 cars, 95.0ms
# Speed: 4.0ms preprocess, 95.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.87 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 11 cars, 92.4ms
# Speed: 3.0ms preprocess, 92.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.84 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 12 cars, 74.4ms
# Speed: 3.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.82 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 14 cars, 57.2ms
# Speed: 3.0ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.79 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 15 cars, 95.8ms
# Speed: 4.5ms preprocess, 95.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.77 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 17 cars, 133.7ms
# Speed: 0.7ms preprocess, 133.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.73 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 14 cars, 171.4ms
# Speed: 12.2ms preprocess, 171.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.70 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 13 cars, 132.2ms
# Speed: 0.0ms preprocess, 132.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.67 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 14 cars, 118.6ms
# Speed: 3.1ms preprocess, 118.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.65 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 14 cars, 117.7ms
# Speed: 8.0ms preprocess, 117.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.62 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 13 cars, 133.1ms
# Speed: 5.2ms preprocess, 133.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.60 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 15 cars, 142.8ms
# Speed: 6.8ms preprocess, 142.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.58 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 11 cars, 113.2ms
# Speed: 4.0ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.56 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 12 cars, 124.2ms
# Speed: 7.3ms preprocess, 124.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.54 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 9 cars, 125.9ms
# Speed: 6.0ms preprocess, 125.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.52 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 10 cars, 120.5ms
# Speed: 6.0ms preprocess, 120.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.50 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 11 cars, 145.5ms
# Speed: 6.6ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.48 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 10 cars, 75.8ms
# Speed: 9.8ms preprocess, 75.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.47 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 11 cars, 82.2ms
# Speed: 17.6ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.45 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 12 cars, 98.4ms
# Speed: 9.4ms preprocess, 98.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.44 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 12 cars, 72.7ms
# Speed: 11.5ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.42 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 12 cars, 74.1ms
# Speed: 3.1ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.41 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 12 cars, 66.2ms
# Speed: 16.1ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.40 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 15 cars, 84.6ms
# Speed: 18.2ms preprocess, 84.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.38 km/h
# Vehicle ID 479.0 is within speed limit.
#
# 0: 384x640 14 cars, 81.4ms
# Speed: 4.3ms preprocess, 81.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.37 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.37 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 104.8ms
# Speed: 12.2ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.35 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.35 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 78.5ms
# Speed: 4.4ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.34 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.34 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 102.0ms
# Speed: 0.0ms preprocess, 102.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.32 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.32 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 76.5ms
# Speed: 4.0ms preprocess, 76.5ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.31 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.31 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 15 cars, 70.2ms
# Speed: 4.2ms preprocess, 70.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.30 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.30 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 72.3ms
# Speed: 2.7ms preprocess, 72.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.29 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.29 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 92.9ms
# Speed: 10.6ms preprocess, 92.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.27 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.27 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 82.8ms
# Speed: 13.6ms preprocess, 82.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.26 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.26 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 87.6ms
# Speed: 3.3ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.25 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.25 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 64.9ms
# Speed: 4.8ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 479.0 Speed: 1.24 km/h
# Vehicle ID 479.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.24 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 69.4ms
# Speed: 14.7ms preprocess, 69.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 477.0 Speed: 1.23 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 10 cars, 67.4ms
# Speed: 16.4ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 477.0 Speed: 1.22 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 11 cars, 75.1ms
# Speed: 7.9ms preprocess, 75.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 477.0 Speed: 1.21 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 60.8ms
# Speed: 7.5ms preprocess, 60.8ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 477.0 Speed: 1.20 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 74.7ms
# Speed: 4.0ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.19 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.19 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 68.4ms
# Speed: 4.7ms preprocess, 68.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.18 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.18 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 85.9ms
# Speed: 7.2ms preprocess, 85.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.17 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.17 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 66.5ms
# Speed: 4.1ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.16 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.16 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 55.7ms
# Speed: 12.4ms preprocess, 55.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.15 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.15 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 11 cars, 85.8ms
# Speed: 10.0ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.14 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.14 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 94.5ms
# Speed: 0.0ms preprocess, 94.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.13 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.13 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 11 cars, 96.4ms
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.12 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.12 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 10 cars, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.11 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.11 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 11 cars, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.11 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.11 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 73.8ms
# Speed: 4.8ms preprocess, 73.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.10 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.10 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.09 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.09 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 58.5ms
# Speed: 5.5ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.08 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.08 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 11 cars, 78.4ms
# Speed: 0.0ms preprocess, 78.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.07 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.07 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 82.6ms
# Speed: 6.5ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.07 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.07 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 10 cars, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.06 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.06 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 11 cars, 70.8ms
# Speed: 0.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.05 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.05 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.04 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.04 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 128.5ms
# Speed: 0.0ms preprocess, 128.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.03 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.04 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 110.4ms
# Speed: 16.7ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.03 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.03 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 78.6ms
# Speed: 12.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.02 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.02 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.01 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.01 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 63.2ms
# Speed: 15.6ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 1.00 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.00 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 113.7ms
# Speed: 15.7ms preprocess, 113.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.99 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 1.00 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 73.3ms
# Speed: 4.8ms preprocess, 73.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.99 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 0.99 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 110.2ms
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.98 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 0.98 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 127.5ms
# Speed: 0.0ms preprocess, 127.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.97 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 0.97 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 13 cars, 163.8ms
# Speed: 6.2ms preprocess, 163.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.96 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 0.96 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 125.3ms
# Speed: 0.0ms preprocess, 125.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.95 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 0.95 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 12 cars, 149.7ms
# Speed: 14.5ms preprocess, 149.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.94 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 0.94 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 15 cars, 129.4ms
# Speed: 0.0ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.94 km/h
# Vehicle ID 480.0 is within speed limit.
# Vehicle ID 477.0 Speed: 0.94 km/h
# Vehicle ID 477.0 is within speed limit.
#
# 0: 384x640 14 cars, 134.4ms
# Speed: 6.9ms preprocess, 134.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.93 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 15 cars, 108.9ms
# Speed: 7.9ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.92 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 14 cars, 117.4ms
# Speed: 15.6ms preprocess, 117.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.91 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 14 cars, 167.5ms
# Speed: 8.5ms preprocess, 167.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.91 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 14 cars, 160.9ms
# Speed: 0.0ms preprocess, 160.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.90 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 15 cars, 117.9ms
# Speed: 7.0ms preprocess, 117.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.89 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 14 cars, 95.2ms
# Speed: 3.3ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.88 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 13 cars, 79.8ms
# Speed: 0.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.88 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 14 cars, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.87 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 13 cars, 46.8ms
# Speed: 16.2ms preprocess, 46.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.87 km/h
# Vehicle ID 480.0 is within speed limit.
#
# 0: 384x640 14 cars, 95.4ms
# Speed: 7.1ms preprocess, 95.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle ID 480.0 Speed: 0.86 km/h
# Vehicle ID 480.0 is within speed limit.

# %%
account_sid = 'ACe8722b25a1c1b7a58bfdc3e1124d43c9'
auth_token = '42bb0aec5fd958190de710444e1a9696'
client = Client(account_sid, auth_token)

# Function to map the predicted class index to a character
def class_to_char(predicted_class):
    if predicted_class < 10:
        return chr(predicted_class + 48)  # Digits 0-9
    elif predicted_class < 36:
        return chr(predicted_class - 10 + 65)  # Uppercase A-Z
    else:
        return chr(predicted_class - 36 + 97)  # Lowercase a-z

# Preprocess the dataset (normalize images)
def preprocess(example):
    image = tf.cast(example['image'], tf.float32) / 255.0
    label = example['label']
    return image, label

# Load and preprocess the EMNIST dataset
emnist_builder = tfds.builder('emnist/byclass')
emnist_builder.download_and_prepare()
emnist = emnist_builder.as_dataset(split='train')
train_dataset = emnist.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Define the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(62, activation='softmax')  # 62 classes for digits and letters
])

# Compile and train the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_dataset, epochs=50)

# %%
def processing_image(img):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) if len(img.shape) > 2 else img
    img_resized = cv2.resize(img_gray, (28, 28))
    img_array = img_resized / 255.0
    return img_array.reshape(1, 28, 28, 1)

# Function to segment characters from the image
def segment_characters(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) if len(img.shape) == 3 else img
    _, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key=lambda x: cv2.boundingRect(x)[0])
    char_bboxes = [cv2.boundingRect(c) for c in contours if cv2.contourArea(c) > 100]
    return char_bboxes, binary

# Folder path containing the images

images = os.listdir(path_of_folder)

# %%
for img_name in images:
    img_path = os.path.join(path_of_folder, img_name)
    
    photo = None
    while photo is None:
        photo = cv2.imread(img_path)
        if photo is None:
            print(f"Retrying: Unable to load image {img_path}")

    if photo is None:
        print(f"Error: Unable to load image {img_path}")
        continue

    # Segment characters
    char_bboxes, binary = segment_characters(photo)
    filtered_bboxes = [bbox for bbox in char_bboxes if bbox[2] > 5 and bbox[3] > 5]
    l = []

    # Predict characters
    for bbox in filtered_bboxes:
        x, y, w, h = bbox
        char_img = binary[y:y + h, x:x + w]
        input_img = processing_image(char_img)
        prediction = model.predict(input_img)
        predicted_class = np.argmax(prediction)
        predicted_char = class_to_char(predicted_class)
        l.append(predicted_char)

        # Draw bounding box and text
        cv2.rectangle(photo, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cvzone.putTextRect(photo, predicted_char, (x, y + 30), scale=1, thickness=1, colorR=(0, 0, 255))

    # Combine characters into a plate number
    plate_number = ''.join(l)
    print(f"Detected Plate Number: {plate_number}")

    # Send message
    try:
        message = client.messages.create(
            body=f"The car with number plate {plate_number} has over-speeded.",
            from_='+12314488432',
            to='+919359645981'
        )
        print(f"Message sent with SID: {message.sid}")
    except Exception as e:
        print(f"Failed to send message: {e}")

    # Display the processed image
    cv2.imshow("Segmented Characters", photo)
    cv2.waitKey(0)

cv2.destroyAllWindows()
